# %%
import requests
import pandas as pd 
import time
from bs4 import BeautifulSoup

origURL = 'https://www.myshiptracking.com/ports-arrivals-departures/?mmsi=&pid=89&type=0&time=1573820700_1573907100&page='

data = []
i = 1
while(i <= 5):
    url = origURL + '%d' % i

    r = requests.get(url)
    soup = BeautifulSoup(r.content, 'html.parser')
    rows = soup.select('div.cs-table div.table-group')
    for row in rows:
        list = row.select_one('div.table-row').text.strip().splitlines()
        type = soup.find('div.table-row' 'img').attrs['src']
        print(type)
        list.append(type)
        data.append(list)
    i+= 1
    time.sleep(0)
# Create the pandas DataFrame 
df = pd.DataFrame(data, columns = ['Event', 'Time', 'Port', 'Vessel', 'VesselType']) 
# print dataframe.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-f634ba7a1304> in <module>
#      16     for row in rows:
#      17         list = row.select_one('div.table-row').text.strip().splitlines()
# ---> 18         type = soup.find('div.table-row' 'img').attrs['src']
#      19         print(type)
#      20         list.append(type)
#
# AttributeError: 'NoneType' object has no attribute 'attrs'

# %%
print(df)
# Out:
#         Event              Time       Port                  Vessel  \
# 0   Departure  2019-11-16 12:24  AMSTERDAM       MAJESTIC TMS [NL]
# 1     Arrival  2019-11-16 12:24  AMSTERDAM          MANTYRANO [NL]
# 2     Arrival  2019-11-16 12:23  AMSTERDAM               WABO [NL]
# 3   Departure  2019-11-16 12:23  AMSTERDAM             PONT 6 [NL]
# 4   Departure  2019-11-16 12:22  AMSTERDAM       VOLHARDING 8 [NL]
# 5   Departure  2019-11-16 12:21  AMSTERDAM            ANTARES [NL]
# 6   Departure  2019-11-16 12:21  AMSTERDAM               FREJ [NL]
# 7   Departure  2019-11-16 12:21  AMSTERDAM        STANLEYSTAD [NL]
# 8     Arrival  2019-11-16 12:18  AMSTERDAM             ADANDI [NL]
# 9     Arrival  2019-11-16 12:16  AMSTERDAM               ANNA [NL]
# 10  Departure  2019-11-16 12:16  AMSTERDAM  ATLANTIC PROGRESS [NL]
# 11    Arrival  2019-11-16 12:16  AMSTERDAM             PONT 6 [NL]
# 12    Arrival  2019-11-16 12:15  AMSTERDAM   JOHANNES VERMEER [NL]
# 13    Arrival  2019-11-16 12:11  AMSTERDAM                KP2 [NL]
# 14  Departure  2019-11-16 12:07  AMSTERDAM               WABO [NL]
# 15  Departure  2019-11-16 12:06  AMSTERDAM         PA5/POLLUX [NL]
# 16  Departure  2019-11-16 12:04  AMSTERDAM             PONT 6 [NL]
# 17  Departure  2019-11-16 12:00  AMSTERDAM                KP2 [NL]
# 18    Arrival  2019-11-16 11:59  AMSTERDAM             NESCIO [NL]
# 19  Departure  2019-11-16 11:57  AMSTERDAM          EEMSTROOM [NL]
# 20    Arrival  2019-11-16 11:56  AMSTERDAM       AMSTELSTROOM [NL]
# 93  Departure  2019-11-16 09:46  AMSTERDAM             PONT 6 [NL]
# 94    Arrival  2019-11-16 09:45  AMSTERDAM         AMSTELPLUS [NL]
# 95  Departure  2019-11-16 09:44  AMSTERDAM            MARKANT [NL]
# 96    Arrival  2019-11-16 09:40  AMSTERDAM             PONT 6 [NL]
# 97    Arrival  2019-11-16 09:36  AMSTERDAM          MAASPOORT [NL]
# 98  Departure  2019-11-16 09:35  AMSTERDAM         AMSTELPLUS [NL]
# 99  Departure  2019-11-16 09:33  AMSTERDAM              BARCA [NL]
#
#             VesselType
# 0   /misc/mst-logo.svg
# 1   /misc/mst-logo.svg
# 2   /misc/mst-logo.svg
# 3   /misc/mst-logo.svg
# 4   /misc/mst-logo.svg
# 5   /misc/mst-logo.svg
# 6   /misc/mst-logo.svg
# 7   /misc/mst-logo.svg
# 8   /misc/mst-logo.svg
# 9   /misc/mst-logo.svg
# 10  /misc/mst-logo.svg
# 11  /misc/mst-logo.svg
# 12  /misc/mst-logo.svg
# 13  /misc/mst-logo.svg
# 14  /misc/mst-logo.svg
# 15  /misc/mst-logo.svg
# 16  /misc/mst-logo.svg
# 17  /misc/mst-logo.svg
# 18  /misc/mst-logo.svg
# 19  /misc/mst-logo.svg
# 20  /misc/mst-logo.svg
# 21  /misc/mst-logo.svg
# 22  /misc/mst-logo.svg
# 23  /misc/mst-logo.svg
# 24  /misc/mst-logo.svg
# 25  /misc/mst-logo.svg
# 26  /misc/mst-logo.svg
# 27  /misc/mst-logo.svg
# 28  /misc/mst-logo.svg
# 29  /misc/mst-logo.svg
# ..                 ...
# 70  /misc/mst-logo.svg
# 71  /misc/mst-logo.svg
# 72  /misc/mst-logo.svg
# 73  /misc/mst-logo.svg
# 74  /misc/mst-logo.svg
# 75  /misc/mst-logo.svg
# 76  /misc/mst-logo.svg
# 77  /misc/mst-logo.svg
# 78  /misc/mst-logo.svg
# 79  /misc/mst-logo.svg
# 80  /misc/mst-logo.svg
# 81  /misc/mst-logo.svg
# 82  /misc/mst-logo.svg
# 83  /misc/mst-logo.svg
# 84  /misc/mst-logo.svg
# 85  /misc/mst-logo.svg
# 86  /misc/mst-logo.svg
# 87  /misc/mst-logo.svg
# 88  /misc/mst-logo.svg
# 89  /misc/mst-logo.svg
# 90  /misc/mst-logo.svg
# 91  /misc/mst-logo.svg
# 92  /misc/mst-logo.svg
# 93  /misc/mst-logo.svg
# 94  /misc/mst-logo.svg
# 95  /misc/mst-logo.svg
# 96  /misc/mst-logo.svg
# 97  /misc/mst-logo.svg
# 98  /misc/mst-logo.svg
# 99  /misc/mst-logo.svg
#
# [100 rows x 5 columns]
