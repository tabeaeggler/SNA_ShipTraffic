# %%
import pandas as pd 
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("./preparedData.csv", index_col=[0]) 
print(df)
# Out:
#                 Event              Time          Port  \
# Unnamed: 0
# 0           Departure  2019-12-08 20:18  PORT DICKSON
# 1           Departure  2019-12-08 20:18   PORT JEROME
# 2           Departure  2019-12-08 20:18     STAVANGER
# 3           Departure  2019-12-08 20:18          TARS
# 4           Departure  2019-12-08 20:18       GOSPORT
# ...               ...               ...           ...
# 249995        Arrival  2019-12-05 14:16    WHITSTABLE
# 249996        Arrival  2019-12-05 14:16        BOGNES
# 249997        Arrival  2019-12-05 14:16     ROZENBURG
# 249998        Arrival  2019-12-05 14:16     STORNOWAY
# 249999        Arrival  2019-12-05 14:16     ROTTERDAM
#
#                                Vessel VesselType
# Unnamed: 0
# 0                    ORKIM POWER [MY]     tanker
# 1                         VAUBAN [FR]  undefined
# 2                          TEDNO [NO]  passenger
# 3                        LOLLAND [DK]  passenger
# 4           SPIRIT OF PORTSMOUTH [GB]  passenger
# ...                               ...        ...
# 249995                LISA MARIE [GB]    fishing
# 249996                  HAMAROEY [NO]  passenger
# 249997               BLANKENBURG [NL]  passenger
# 249998                  VOE EARL [GB]        tug
# 249999                     STERN [NL]      cargo
#
# [250000 rows x 5 columns]

# %%
events = set(df.Event)
print(events)
# Out:
# {'Departure', 'Arrival'}

# %%
fig, ax = plt.subplots(figsize=(4,6))
sns.countplot(x=df.Event, data=df)
plt.show()

# %%
vessels = set(df.Vessel)
print(len(vessels))
print(vessels)
# Out:
# 43633
# {'MILA [NL]', 'XIA GANG TUO 25 [CN]', 'MV BALENO [PH]', 'MILAN [DE]', 'LINTER 1 [UA]', 'T/B ROMULO [ES]', 'VB TRON [ES]', 'RYUOH MARU [JP]', 'WIJKERZAND [DE]', 'CAN-D [TR]', 'PILOT93 [HK]', 'RABA [SE]', 'KOREA PEACE [KR]', 'PACIFIC ARROW [US]', 'AGIA PARASKEVI [GR]', 'POMPEI [BJ]', 'LOGAN B [US]', 'COSCO HAIFA [MY]', 'CRYSTAL CUTTER 3 [AU]', 'BOCHEM CHENNAI [FR]', 'EVER DECENT [MY]', 'SAN ALESSIO [US]', 'VIGOROUS [UA]', 'MV HELAM [NG]', 'MERAUKE [ID]', 'WEGA [DE]', 'NUEVO TRES COSTAS [ES]', 'R6-ORKA>>_ [BE]', 'UK46 WILLEKE [NL]', 'RAINBOW [US]', 'MASARRAH [SA]', 'ARK [JP]', 'M/T PATEA [DE]', 'ARCIMBALDO [BR]', 'MSC PILAR [GR]', 'JOEL [NL]', 'LA BLANCA [NL]', 'SOLVI=KARIN [SE]', "NOR'EASTER [US]", 'HARVEY SUPPORTER [US]', 'NEPTUNE1 [IR]', 'BDS-SURVEYOR [NL]', 'ERTEPELLER [NL]', 'CAPE TOWN HIGHWAY [JP]', 'MEYA [MA]', 'SILVER HARVESTER [GB]', 'MISS AVA [US]', 'KIMBERLY C [US]', 'BRISBANE [AU]', '12008 [CN]', 'TSS 35 [SG]', 'LSL EXPRESS [SG]', 'RONJA EXPLORER [NO]', 'MEGALOPOLIS [PE]', 'CORONA [IN]', 'ZUHRA II [KE]', 'NEW GOLDENBRIDGE VII [CN]', 'JELLE AUK
'MERWEDEGRACHT [AU]', 'GO-20 MARIA [NL]', 'ZILVERSTAD [NL]', 'IL KWANG NO.3 [KR]', 'SALTIGA [AU]', 'HEL-111 [PL]', 'LONG DA SHENG [CN]', 'THERESA JILIN [TW]', 'ARAMOANA [NZ]', 'SHINPUKUMARU22 [JP]', 'AQUATA [BE]', 'ASD.GEMA 5 [ID]', 'RESCUE 19A [ZA]', 'CAPE HOPE [TT]', 'POLA PELAGIA [ES]', 'THOPAS [DK]', 'HOEGH AMSTERDAM [DE]', 'NORDINDEPENDENCE [DE]', 'STELLAR WINDSOR [TH]', 'MALTE RAMBOW [CN]', 'NSS-1002 [RU]', 'EXPRESS ATHENS [MA]', 'CAAN [NL]', 'YU BONG 1HO [ID]', 'CAPE HATTERAS [US]', 'M/V JENNA [GB]', 'HOIHOW [DE]', 'TAL-LOISE V [ES]', 'HAIGANG122 [CN]', 'SVITZER PELLA [BH]', 'PACIFIC DREAM [JP]', 'SING WAY 12 [HK]', 'MAJ RICHARD WINTERS [CA]', 'TIAN REN [KR]', 'ALONSO DE CHAVES [ES]', 'VB FURIA [ES]', 'HIRUNDO [BL]', 'KVB VERA [NL]', 'EVIACEMENT III [ES]', 'L C T  808 [PH]', 'F/V NARVAL [FR]', 'SC CONNECTOR [NO]', 'SEATRUCK PRECISION [GB]', 'YUE XIN HE 238 [CN]', 'TAI 00777 [TW]', 'FLAG SEAMAN [ ...

# %%
fig, ax = plt.subplots(figsize=(15,8))
sns.countplot(x=df.VesselType, data=df, order=df.VesselType.value_counts().index)
plt.show()

# %%
ports = set(df.Port)
print(len(ports))
print(ports)
# Out:
# 4044
# {'SANTANDER', nan, 'SELDOVIA', 'PUERTO CHINCUI', 'POZZALLO', 'GREYMOUTH', 'KOKKOLA', 'SAN MARCOS', 'OPUA', 'YAMAGAWA', 'STEINSHAMN', 'LYNESS', 'KATS', 'JURUTI', 'MONDORF', "ST MARGARET'S HOPE", 'BANGGAI', 'DRUMMOYNE SYDNEY', 'EUREKA PUBLIC', 'SHANTOU', 'WESSELING', 'BRIXHAM', 'FOURNI', 'NIEUWE MEER', 'GROTO', 'LOMONOSOV', 'WITTINGEN', 'DRACHTEN', 'HAKATASHIMA', 'OLDENBURG', 'JINHAI HEAVY INDUSTR', 'NAKHODKA', 'TARS', 'VENTURA', 'LIMAY', 'IPSWICH', 'VESUVIUS (BC)', 'HACHINOHE', 'VIESTE', 'MINA SULMAN', 'MASBATE', 'DAKHLA', 'MONTOIR', 'FLEETWOOD', 'PUERTO DEL ROSARIO', 'BEIRUT', 'INCHEON', 'PA-TOU-TZU', 'SANTOS', 'DUBA', 'TUAPSE', 'STURGEON BAY', 'BILDUDALUR', 'HIGASHIHARIMA', 'HAVOYSUND', 'POBRA DO CARAMINAL', 'CHIPIONA', 'VEGHEL', 'GASPE', 'SANTA FE', 'AMBON', 'BOLIVAR', 'YANGJIANG', 'EIDI', 'KLEINOSTHEIM', 'ALGES', 'ANDIKYRA', 'FLENSBURG', 'MARETTIMO', 'MONTEVERDE', 'HWASUN', 'PORT DE BOUC', 'PLAYA BLANCA', 'HANK', 'PORTO NOGARO', 'HASSELBY', 'HELTERMAA', 'MATNOG', 'CHIWAN', 'PORTIMAO', 'MALONGO', 'YOWIE BAY', 'MALLAIG', 'PADUCAH', 'BOLUNGARVIK', 'PORTO DO ACU', "L'ILE ROUSSE", 'AJOS', 'PEARL HARBOR', 'YANTIAN', 'GYALI', 'LOONSEWAARD', 'RABAUL', 'CANAKKALE', 'CAPE CUVIER', 'OOSTWATERING', 'AUKRA', 'QINGDAO', 'ORKANGER', 'REPOSAARI', 'AGIOS ISIDOROS', 'BERGEN OP ZOOM', 'SYRI', 'TRAENA', 'PORT COLBORNE', 'BRIDPORT', 'TORRE ANNUNZIATA', 'ASALUYEH', 'RAVELS', 'RAYONG', 'PAAL', 'KOUROU', 'LAVERA', 'VORDINGBORG VESTHAVN', 'FAK FAK', 'NABIRE', 'CHANGXINDAO', 'SVENDBORG', 'FORT DE FRANCE', 'SUMARTIN', 'STRANRAER', 'NEA STIRA', 'GARY HARBOR', 'MOROZAKI', 'USHUAIA', 'TKON', 'DAVAO', 'DONGYING', 'KARACHI', 'USTKA', 'BREKSTAD', 'SHIRIYAMAZAKI', 'PUERTO MADERO', 'GILIMANUK', 'GILLELEJE', 'DORTMUND', 'EARLE NAVAL STATION', 'HERNE', 'PORVENIR', 'FEODOSIYA', 'BOWEN ISLAND', 'TURGUTREIS', 'FULFORD HARBOUR', 'OLEN', 'GRONINGEN', 'PENNESHAW', 'HITACHI', 'KAFUKA', 'ALAMEDA DEL SIBONEY', 'KARUMBA', 'HIDDENSEE', 'PORTO', 'GERMERSHEIM', 'SIMONS TOWN', 'CANCUN', 'HALF MOON CAY', 'DILI', 'GETARIA', 'MATANE ', 'SVANESUND', 'SOGNDAL', 'HALDEN', 'JATNAVEGUR', 'BIG CREEK', 'RICHARDS BAY', 'ACAJUTLA', 'SAN PEDRO', 'NARVIK', 'KAINAN', 'IWAKUNI', 'YAIZU', 'TOSHIMA ISLAND', 'JASTARNIA', 'PORT TOWNSEND', 'ORNSKOLDSVIK', 'CIUDAD DE CORRIENTES', 'NIEHL', 'MAOLO LAILAI', 'VIRTSU', 'LABUANA BAJO', 'ZIGUINCHOR', 'WELCOME', 'PAITON', 'TACLOBAN', 'KUGURIZAKA', 'FANARI', 'MOOLOOLABA', 'LA BARRE DE MONTS', 'KOLLAFJORDUR', 'STRATTON HALL', 'EMAM HASAN', 'BARRANQUILLA', 'ARZEW', 'TAICANG', 'KUMAI', 'BYAH', 'CHARLOTTETOWN', 'SHIMOTSU', 'TANANGER', 'ANNABA', 'CHIMBOTE', 'PORT FITZROY', 'SIRACUSA', 'DONGES', 'METLAKATLA', 'SATTAHIP', 'WAALWIJK', 'DUNKERQUE', 'CHABAHAR', 'STEVESTON', 'LA MARTINIERE (LE PE', 'CAPE TOWN', 'KUWAIT', 'BONN', 'HAZAR', 'CHIBA', 'PORTO EMPEDOCLE', 'YAMADA', 'RAUMA', 'PONCE', 'SOVIK', 'PAIHIA', 'ROCKPORT', 'PLOMIN', 'BENGHAZI', 'TWEED HEADS', 'SANDNES', 'HONNINGSVAAG', 'SAPE', 'HUANGHUA', 'NESKAUPSTADUR', 'FUZHOU', 'OYRI', 'SHINMONJI', 'HAINES', 'PACHI', 'LUDWIGSHAFEN', 'DANGAY', 'AMSTERDAM', 'STRALSUND', 'SANTA BARBARA', 'KEFALONIA-LIXOURI', 'BUCHANAN', 'PLAYA DEL CARMEN', 'XOROSTASI', 'HOOPTE', 'WORMS', 'KITHIRA', 'KYLLINI', 'RAS AL MISHAB', 'GRAVESEND', 'SCHELLINGWOUDE', 'PASAI SAN PEDRO', 'CHIRIQUI GRANDE', 'WEMYSS BAY', 'LAUTOKA', 'HOLY ISLAND', 'SIDON', 'GLADSTONE', 'PREKO', 'OMINATO', 'BANJARMASIN', 'BARGE TERMINAL BORN', 'BROWNSVILLE', 'NORDDEICH', 'BRAUNSCHWEIG', 'GLENELG', 'MEKAR PUTIH', 'GEORGETOWN', 'IGEROY', 'NEA MICHANIONA', 'YANGPU', 'GANDIA', 'HILLARY', 'REES', 'CHERRY POINT', 'OCEAN FALLS', 'STROMSTAD', 'KYLEAKIN', 'WAIKAWA', 'NEWLYN', 'BRIDGEPORT', 'TURKMENBASHI', 'SITKA', 'FESTVAG', 'MOLNSKOGEN', 'NAKANOSEKI', 'FUKUYAMA', 'KETRON ISLAND', 'TAKUMA', 'SALVADOR', 'BAIE COMEAU', 'WISMAR', 'BAKAR', 'LAMBERTS BAY', 'NAOUSA', 'BURRIANA', 'SAN JUAN', 'KANSAS CITY', 'PESCARA', 'DONGJIAKOU', 'GABES', 'DALIAN', 'BRATTVAG', 'FUENTERRABIA', 'ZEELAND REFINERY', 'KLAKSVIK', 'GAASTMEER', 'FALMOUTH', 'AIGIO', 'WAINGAPU', 'PORTO VELHO', 'SARROCH', ...

# %%
df_timetable = pd.read_csv("./timetable.csv", index_col=[0]) 
print(df_timetable)
# Out:
#        DeparturePort     DepartureTime ArrivalPort       ArrivalTime  \
# 0           GUSTAVIA  2019-12-05 19:59    GUSTAVIA  2019-12-06 09:56
# 1           GUSTAVIA  2019-12-06 12:52    GUSTAVIA  2019-12-07 10:06
# 2      FREEPORT (TX)  2019-12-05 20:10     HOUSTON  2019-12-06 07:59
# 3              KAWAU  2019-12-06 20:05       KAWAU  2019-12-07 03:08
# 4              KAWAU  2019-12-07 22:17       KAWAU  2019-12-08 00:26
# ...              ...               ...         ...               ...
# 98287         TUAPSE  2019-12-07 04:39      TUAPSE  2019-12-07 04:42
# 98288         TUAPSE  2019-12-07 07:55      TUAPSE  2019-12-07 08:51
# 98289         TUAPSE  2019-12-07 12:13      TUAPSE  2019-12-07 12:23
# 98290         TUAPSE  2019-12-07 18:53      TUAPSE  2019-12-07 19:43
# 98291         TUAPSE  2019-12-08 13:50      TUAPSE  2019-12-08 14:09
#
#                       Vessel VesselType
# 0               HIRUNDO [BL]      cargo
# 1               HIRUNDO [BL]      cargo
# 2           DEL WILKINS [US]        tug
# 3                KRABAT [NZ]      yacht
# 4                KRABAT [NZ]      yacht
# ...                      ...        ...
# 98287  KAPITAN AVDYUKOV [RU]        tug
# 98288  KAPITAN AVDYUKOV [RU]        tug
# 98289  KAPITAN AVDYUKOV [RU]        tug
# 98290  KAPITAN AVDYUKOV [RU]        tug
# 98291  KAPITAN AVDYUKOV [RU]        tug
#
# [98292 rows x 6 columns]
